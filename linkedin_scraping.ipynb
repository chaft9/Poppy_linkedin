# %%
import os, random, sys, time
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains  #Permet de faire des entrees clavier
from selenium.webdriver.common.keys import Keys

""" Ce programme à pour nom Poppy """

# %%
""" Login à Linkedin """


s=Service("C:/Users/Damien/PycharmProjects/linkedin_scrap/chromedriver.exe") # Indique la route ou se trouve le dossier chrome driver
browser = webdriver.Chrome(service=s) # L'on instancie browser qui vas nous permettre de lancer des pages web
url="https://www.linkedin.com/uas/login" #URL qui vas rediriger vers la login page
browser.get(url) # Lance la page web
time.sleep(2)
file = open("id.txt") # Poppy vas open le fichier ou ce trouve nos id de connexion
lines = file.readlines()
username = lines[0] # première ligne = username
password = lines[1] # seconde ligne = password
elementID = browser.find_element(By.ID, 'username') # l'on as obtenu l'id 'username' en inspectant le code source de la page login
elementID.send_keys(username) # Poppy vas écrire le username sur la page login
elementID = browser.find_element(By.ID, 'password') 
elementID.send_keys(password) # Poppy écrit le password 

elementID.submit() # Click sur connexion ou press enter, comme tu veux.

# %%
""" Recherche les société souhaiter """

elementID = browser.find_element(By.ID, "global-nav-search").click()
time.sleep(2)
compagny = "sunbren"
elementID = browser.find_element(by=By.XPATH, value="//input[@placeholder='Recherche']").send_keys(compagny)
ActionChains(browser).key_down(Keys.ENTER).perform()
time.sleep(2)
elementCLASS = browser.find_element(By.XPATH, value="//a[@class='app-aware-link']").click()
time.sleep(2)
elementCLASS = browser.find_element(By.XPATH, value="//a[@class='ember-view']").click()
#ember-view
#ActionChains(browser).key_down(Keys.ENTER).perform()

# %%
""" Obtenir les noms des employée de Compagny X """

def getNewProfilIDs(soup):
    nameProfil = []
    profilesID = []
    pav = soup.find('div', {'class': "search-marvel-srp"})
    all_names = pav.findAll('div', {'class': "search-results-container"})
    print(all_names)
    for name in names:
        if name == str(name):
            nameProfil.append(name)
    return nameProfil

print(getNewProfilIDs(BeautifulSoup(browser.page_source)))
# Out:
# [<div class="search-results-container">
# <h2 class="pb2 t-black--light t-14">
# <!-- -->6 résultats<!-- -->
# </h2>
# <div class="ph0 pv2 artdeco-card mb2">
# <!-- -->
# <ul class="reusable-search__entity-result-list list-style-none">
# <li class="reusable-search__result-container">
# <div class="entity-result" data-chameleon-result-urn="urn:li:member:4900421">
# <div class="entity-result__item">
# <div class="entity-result__universal-image">
# <div class="display-flex align-items-center">
# <!-- -->
# <a aria-hidden="true" class="app-aware-link scale-down" href="https://www.linkedin.com/in/fabrice-koszyk?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAABKxkUB1AA9_xFZ19C0fnFFcB3pDnga0Ho">
# <div class="ivm-image-view-model">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <!-- -->
# <div class="presence-entity presence-entity--size-3">
# <img alt="Fabrice Koszyk" class="presence-entity__image ivm-view-attr__img--centered EntityPhoto-circle-3 EntityPhoto-circle-3 lazy-image ember-view" id="ember410" loading="lazy" src="https://media-exp2.licdn.com/dms/image/C5103AQG2Th7M6GwGig/profile-displayphoto-shrink_100_100/0/1516316659462?e=1661385600&amp;v=beta&amp;t=r398PpMrk1ZXjiwg1ekBrunRLyPqgc53k5Mno6DinwQ"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator hidden presence-indicator--size-3">
# <span class="visually-hidden">
#       Le statut est hors ligne
#       </span>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="entity-result__content entity-result__divider pt3 pb3 t-12 t-black--light">
# <div class="mb1">
# <div class="t-roman t-sans">
# <div class="display-flex">
# <span class="entity-result__title-line entity-result__title-line--2-lines">
# <span class="entity-result__title-text t-16">
# <a class="app-aware-link" href="https://www.linkedin.com/in/fabrice-koszyk?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAABKxkUB1AA9_xFZ19C0fnFFcB3pDnga0Ho">
# <span dir="ltr"><span aria-hidden="true"><!-- -->Fabrice Koszyk<!-- --></span><span class="visually-hidden"><!-- -->Voir le profil de Fabrice Koszyk<!-- --></span></span>
# </a>
# <span class="entity-result__badge t-14 t-normal t-black--light">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 2e<!-- --></span><span class="visually-hidden"><!-- -->Relation de 2e niveau<!-- --></span>
# </span>
# </div>
# </span>
# </span>
# </span>
# <span aria-hidden="true" class="entity-result__badge-overflow align-self-flex-end t-14 t-normal t-black--light flex-shrink-zero">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 2e<!-- --></span><span class="visually-hidden"><!-- -->Relation de 2e niveau<!-- --></span>
# </span>
# </div>
# </span>
# </div>
# </div>
# <div class="linked-area flex-1 cursor-pointer">
# <div>
# <div class="entity-result__primary-subtitle t-14 t-black t-normal">
# <!-- -->CEO chez Serenicity<!-- -->
# </div>
# <div class="entity-result__secondary-subtitle t-14 t-normal">
# <!-- -->Lyon et périphérie<!-- -->
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# <div class="entity-result__insights t-12">
# <div class="entity-result__simple-insight">
# <div class="ivm-image-view-model entity-result__simple-insight-image flex-shrink-zero mr2">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <li-icon aria-hidden="true" size="small" type="people-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M14 11.75V15H9v-3.25A1.75 1.75 0 0110.75 10h1.5A1.75 1.75 0 0114 11.75zM11.5 9A2.5 2.5 0 109 6.5 2.5 2.5 0 0011.5 9zM5 1a3 3 0 103 3 3 3 0 00-3-3zm.75 7h-1.5A2.25 2.25 0 002 10.25V15h6v-4.75A2.25 2.25 0 005.75 8z"></path>
# </svg></li-icon>
# </div>
# </div>
# <div class="entity-result__simple-insight-text-container">
# <span class="entity-result__simple-insight-text entity-result__simple-insight-text--small">
# <a class="app-aware-link" href="https://www.linkedin.com/in/ACoAAAAA8wUBcWq9EYIrVMvQ5YdOXYI4MYAF344?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAAA8wUBcWq9EYIrVMvQ5YdOXYI4MYAF344" target="_self"><strong><!-- -->Axel Dreyfus<!-- --></strong></a><span class="white-space-pre"> </span>et<span class="white-space-pre"> </span><a class="app-aware-link" href="https://www.linkedin.com/in/ACoAADNR2OkBSHqxwX-kZMtKq2FdPdMBFglLqpw?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADNR2OkBSHqxwX-kZMtKq2FdPdMBFglLqpw" target="_self"><strong><!-- -->Yves B.<!-- --></strong></a><span class="white-space-pre"> </span>sont des relations en commun<!-- -->
# </span>
# <!-- --> </div>
# </div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <div class="entity-result__actions entity-result__divider">
# <!-- -->
# <div>
# <button aria-label="Invitez Fabrice Koszyk à rejoindre votre réseau" class="artdeco-button artdeco-button--2 artdeco-button--secondary ember-view" id="ember447"><!-- -->
# <span class="artdeco-button__text">
#     Se connecter
# </span></button>
# <!-- -->
# <!-- -->
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# </li>
# <li class="reusable-search__result-container">
# <div class="entity-result" data-chameleon-result-urn="urn:li:member:59123690">
# <div class="entity-result__item">
# <div class="entity-result__universal-image">
# <div class="display-flex align-items-center">
# <!-- -->
# <a aria-hidden="true" class="app-aware-link scale-down" href="https://www.linkedin.com/in/ericpetrotto?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAOGJ-oBrw-gCuxOQGBXfwiO4dB6RBPuPXU">
# <div class="ivm-image-view-model">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <!-- -->
# <div class="presence-entity presence-entity--size-3">
# <img alt="Eric PETROTTO" class="presence-entity__image ivm-view-attr__img--centered EntityPhoto-circle-3 EntityPhoto-circle-3 lazy-image ember-view" id="ember411" loading="lazy" src="https://media-exp2.licdn.com/dms/image/C4D03AQE93pxFqQAOqw/profile-displayphoto-shrink_100_100/0/1516768135145?e=1661385600&amp;v=beta&amp;t=D1bdt2Ei6tpNpQBCOGbmEeTd62Netnqo2nsr2RQN778"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator hidden presence-indicator--size-3">
# <span class="visually-hidden">
#       Le statut est hors ligne
#       </span>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="entity-result__content entity-result__divider pt3 pb3 t-12 t-black--light">
# <div class="mb1">
# <div class="t-roman t-sans">
# <div class="display-flex">
# <span class="entity-result__title-line entity-result__title-line--2-lines">
# <span class="entity-result__title-text t-16">
# <a class="app-aware-link" href="https://www.linkedin.com/in/ericpetrotto?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAOGJ-oBrw-gCuxOQGBXfwiO4dB6RBPuPXU">
# <span dir="ltr"><span aria-hidden="true"><!-- -->Eric PETROTTO<!-- --></span><span class="visually-hidden"><!-- -->Voir le profil de Eric PETROTTO<!-- --></span></span>
# </a>
# <span class="entity-result__badge t-14 t-normal t-black--light">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 2e<!-- --></span><span class="visually-hidden"><!-- -->Relation de 2e niveau<!-- --></span>
# </span>
# </div>
# </span>
# </span>
# </span>
# <span aria-hidden="true" class="entity-result__badge-overflow align-self-flex-end t-14 t-normal t-black--light flex-shrink-zero">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 2e<!-- --></span><span class="visually-hidden"><!-- -->Relation de 2e niveau<!-- --></span>
# </span>
# </div>
# </span>
# </div>
# </div>
# <div class="linked-area flex-1 cursor-pointer">
# <div>
# <div class="entity-result__primary-subtitle t-14 t-black t-normal">
# <!-- -->PDG, DOOD [Digital Orchestra of Data]<!-- -->
# </div>
# <div class="entity-result__secondary-subtitle t-14 t-normal">
# <!-- -->Lyon<!-- -->
# </div>
# </div>
# </div>
# </div>
# <div class="linked-area flex-1 cursor-pointer">
# <p class="entity-result__summary entity-result__summary--2-lines t-12 t-black--light mb1">
# <span aria-hidden="true"><!-- -->Sujets de prédilection : #economiebleue, #cybersécurité, #economiecirculaire, #diversiteculturelle et #humaniténumérique<!-- --></span><span class="visually-hidden"><!-- -->Sujets de prédilection : hashtag economiebleue, hashtag cybersécurité, hashtag economiecirculaire, hashtag diversiteculturelle et hashtag humaniténumérique<!-- --></span>
# </p>
# </div>
# <div class="entity-result__insights t-12">
# <div class="entity-result__simple-insight">
# <div class="ivm-image-view-model entity-result__simple-insight-image flex-shrink-zero mr2">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <li-icon aria-hidden="true" size="small" type="people-icon"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M14 11.75V15H9v-3.25A1.75 1.75 0 0110.75 10h1.5A1.75 1.75 0 0114 11.75zM11.5 9A2.5 2.5 0 109 6.5 2.5 2.5 0 0011.5 9zM5 1a3 3 0 103 3 3 3 0 00-3-3zm.75 7h-1.5A2.25 2.25 0 002 10.25V15h6v-4.75A2.25 2.25 0 005.75 8z"></path>
# </svg></li-icon>
# </div>
# </div>
# <div class="entity-result__simple-insight-text-container">
# <span class="entity-result__simple-insight-text entity-result__simple-insight-text--small">
# <!-- -->5,3 000 abonnés •<span class="white-space-pre"> </span><a class="app-aware-link" href="https://www.linkedin.com/in/ACoAAAAA8wUBcWq9EYIrVMvQ5YdOXYI4MYAF344?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAAA8wUBcWq9EYIrVMvQ5YdOXYI4MYAF344" target="_self"><strong><!-- -->Axel Dreyfus<!-- --></strong></a><span class="white-space-pre"> </span>et<span class="white-space-pre"> </span><a class="app-aware-link" href="https://www.linkedin.com/in/ACoAABhPXXIBuB60I6hk2pAzJtHBOhRNg8gUPyQ?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABhPXXIBuB60I6hk2pAzJtHBOhRNg8gUPyQ" target="_self"><strong><!-- -->Romain Burel<!-- --></strong></a><span class="white-space-pre"> </span>sont des relations en commun<!-- -->
# </span>
# <!-- --> </div>
# </div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# <div class="entity-result__actions entity-result__divider">
# <!-- -->
# <div>
# <!-- --> <button aria-label="Suivre" class="artdeco-button artdeco-button--2 artdeco-button--secondary ember-view" data-control-id="7yablq8UTtmYvi1754lFdw==" data-control-name="entity_action_primary" data-test-reusable-search-primary-action="true" id="ember448"><!-- -->
# <span class="artdeco-button__text">
#     Suivre
# </span></button>
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# </li>
# <li class="reusable-search__result-container">
# <div class="entity-result" data-chameleon-result-urn="urn:li:member:8351917">
# <div class="entity-result__item">
# <div class="entity-result__universal-image">
# <div class="display-flex align-items-center">
# <!-- -->
# <a aria-hidden="true" class="app-aware-link scale-down" href="https://www.linkedin.com/in/baptistecasnedi?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAB_cK0BPi0T4rWtVWB_YqD2wzufwlbZHxY">
# <div class="ivm-image-view-model">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <!-- -->
# <div class="presence-entity presence-entity--size-3">
# <img alt="Baptiste Casnedi" class="presence-entity__image ivm-view-attr__img--centered EntityPhoto-circle-3 EntityPhoto-circle-3 lazy-image ember-view" id="ember412" loading="lazy" src="https://media-exp2.licdn.com/dms/image/C5603AQEUioYaIjNXxA/profile-displayphoto-shrink_100_100/0/1521742618679?e=1661385600&amp;v=beta&amp;t=ubz-d_1gXyt3ixenAyz9EGT9lOQDXtZRkD2F4J5lu1Q"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator hidden presence-indicator--size-3">
# <span class="visually-hidden">
#       Le statut est hors ligne
#       </span>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="entity-result__content entity-result__divider pt3 pb3 t-12 t-black--light">
# <div>
# <div class="t-roman t-sans">
# <div class="display-flex">
# <span class="entity-result__title-line entity-result__title-line--2-lines">
# <span class="entity-result__title-text t-16">
# <a class="app-aware-link" href="https://www.linkedin.com/in/baptistecasnedi?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAB_cK0BPi0T4rWtVWB_YqD2wzufwlbZHxY">
# <span dir="ltr"><span aria-hidden="true"><!-- -->Baptiste Casnedi<!-- --></span><span class="visually-hidden"><!-- -->Voir le profil de Baptiste Casnedi<!-- --></span></span>
# </a>
# <span class="entity-result__badge t-14 t-normal t-black--light">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 3e et +<!-- --></span><span class="visually-hidden"><!-- -->Relation de 3e niveau et plus<!-- --></span>
# </span>
# </div>
# </span>
# </span>
# </span>
# <span aria-hidden="true" class="entity-result__badge-overflow align-self-flex-end t-14 t-normal t-black--light flex-shrink-zero">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 3e et +<!-- --></span><span class="visually-hidden"><!-- -->Relation de 3e niveau et plus<!-- --></span>
# </span>
# </div>
# </span>
# </div>
# </div>
# <div class="linked-area flex-1 cursor-pointer">
# <div>
# <div class="entity-result__primary-subtitle t-14 t-black t-normal">
# <!-- -->J'apporte de la sérénité aux équipes de développement pour qu’elles se concentrent sur leur métier qui les rémunère<!-- -->
# </div>
# <div class="entity-result__secondary-subtitle t-14 t-normal">
# <!-- -->Avignon<!-- -->
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# <!-- --> </div>
# <div class="entity-result__actions entity-result__divider">
# <!-- -->
# <div>
# <div class="entry-point">
# <div></div>
# <button class="artdeco-button artdeco-button--2 artdeco-button--secondary ember-view" id="ember449"><!-- -->
# <span class="artdeco-button__text">
#     Message
# </span></button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# </li>
# <li class="reusable-search__result-container">
# <div class="entity-result" data-chameleon-result-urn="urn:li:member:623803349">
# <div class="entity-result__item">
# <div class="entity-result__universal-image">
# <div class="display-flex align-items-center">
# <!-- -->
# <a aria-hidden="true" class="app-aware-link scale-down" href="https://www.linkedin.com/in/hello-sunbren-385ab1154?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACUue9UBFRap5SUeAEe7z8Y4LYNW8ExyfAA">
# <div class="ivm-image-view-model">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <div class="EntityPhoto-circle-3-ghost-person ivm-view-attr__ghost-entity">
# <div class="visually-hidden">Hello Sunbren</div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="entity-result__content entity-result__divider pt3 pb3 t-12 t-black--light">
# <div>
# <div class="t-roman t-sans">
# <div class="display-flex">
# <span class="entity-result__title-line entity-result__title-line--2-lines">
# <span class="entity-result__title-text t-16">
# <a class="app-aware-link" href="https://www.linkedin.com/in/hello-sunbren-385ab1154?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACUue9UBFRap5SUeAEe7z8Y4LYNW8ExyfAA">
# <span dir="ltr"><span aria-hidden="true"><!-- -->Hello Sunbren<!-- --></span><span class="visually-hidden"><!-- -->Voir le profil de Hello Sunbren<!-- --></span></span>
# </a>
# <span class="entity-result__badge t-14 t-normal t-black--light">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 3e et +<!-- --></span><span class="visually-hidden"><!-- -->Relation de 3e niveau et plus<!-- --></span>
# </span>
# </div>
# </span>
# </span>
# </span>
# <span aria-hidden="true" class="entity-result__badge-overflow align-self-flex-end t-14 t-normal t-black--light flex-shrink-zero">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 3e et +<!-- --></span><span class="visually-hidden"><!-- -->Relation de 3e niveau et plus<!-- --></span>
# </span>
# </div>
# </span>
# </div>
# </div>
# <div class="linked-area flex-1 cursor-pointer">
# <div>
# <div class="entity-result__primary-subtitle t-14 t-black t-normal">
# <!-- -->Informaticienne chez Cblue<!-- -->
# </div>
# <div class="entity-result__secondary-subtitle t-14 t-normal">
# <!-- -->Saint-André<!-- -->
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# <!-- --> </div>
# <div class="entity-result__actions entity-result__divider">
# <!-- -->
# <div>
# <button aria-label="Invitez Hello Sunbren à rejoindre votre réseau" class="artdeco-button artdeco-button--2 artdeco-button--secondary ember-view" id="ember450"><!-- -->
# <span class="artdeco-button__text">
#     Se connecter
# </span></button>
# <!-- -->
# <!-- -->
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# </li>
# <li class="reusable-search__result-container">
# <div class="entity-result" data-chameleon-result-urn="urn:li:member:234451963">
# <div class="entity-result__item">
# <div class="entity-result__universal-image">
# <div class="display-flex align-items-center">
# <!-- -->
# <a aria-hidden="true" class="app-aware-link scale-down" href="https://www.linkedin.com/in/jean-fernandez-27762666?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAA35c_sB0yiNEmGW02o6YlFb3O_L2NPQIwA">
# <div class="ivm-image-view-model">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <!-- -->
# <div class="presence-entity presence-entity--size-3">
# <img alt="JEAN FERNANDEZ" class="presence-entity__image ivm-view-attr__img--centered EntityPhoto-circle-3 EntityPhoto-circle-3 lazy-image ember-view" id="ember413" loading="lazy" src="https://media-exp2.licdn.com/dms/image/C4D03AQGgq-mTi-hhTQ/profile-displayphoto-shrink_100_100/0/1626696981257?e=1661385600&amp;v=beta&amp;t=M0fmTgIxfqfwrne53usB4V2ozR1KMbdo4gqml259oe4"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator hidden presence-indicator--size-3">
# <span class="visually-hidden">
#       Le statut est hors ligne
#       </span>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="entity-result__content entity-result__divider pt3 pb3 t-12 t-black--light">
# <div>
# <div class="t-roman t-sans">
# <div class="display-flex">
# <span class="entity-result__title-line entity-result__title-line--2-lines">
# <span class="entity-result__title-text t-16">
# <a class="app-aware-link" href="https://www.linkedin.com/in/jean-fernandez-27762666?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAA35c_sB0yiNEmGW02o6YlFb3O_L2NPQIwA">
# <span dir="ltr"><span aria-hidden="true"><!-- -->JEAN FERNANDEZ<!-- --></span><span class="visually-hidden"><!-- -->Voir le profil de JEAN FERNANDEZ<!-- --></span></span>
# </a>
# <span class="entity-result__badge t-14 t-normal t-black--light">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 3e et +<!-- --></span><span class="visually-hidden"><!-- -->Relation de 3e niveau et plus<!-- --></span>
# </span>
# </div>
# </span>
# </span>
# </span>
# <span aria-hidden="true" class="entity-result__badge-overflow align-self-flex-end t-14 t-normal t-black--light flex-shrink-zero">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 3e et +<!-- --></span><span class="visually-hidden"><!-- -->Relation de 3e niveau et plus<!-- --></span>
# </span>
# </div>
# </span>
# </div>
# </div>
# <div class="linked-area flex-1 cursor-pointer">
# <div>
# <div class="entity-result__primary-subtitle t-14 t-black t-normal">
# <!-- -->Président Marketime Hub<!-- -->
# </div>
# <div class="entity-result__secondary-subtitle t-14 t-normal">
# <!-- -->Lyon et périphérie<!-- -->
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# <!-- --> </div>
# <div class="entity-result__actions entity-result__divider">
# <!-- -->
# <div>
# <div class="entry-point">
# <div></div>
# <button class="artdeco-button artdeco-button--2 artdeco-button--secondary ember-view" id="ember453"><!-- -->
# <span class="artdeco-button__text">
#     Message
# </span></button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# </li>
# <li class="reusable-search__result-container">
# <div class="entity-result" data-chameleon-result-urn="urn:li:member:890875539">
# <div class="entity-result__item">
# <div class="entity-result__universal-image">
# <div class="display-flex align-items-center">
# <!-- -->
# <a aria-hidden="true" class="app-aware-link scale-down" href="https://www.linkedin.com/in/anja-fran%C3%A7ois-randriavaniaina-b8342820a?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADUZrpMB_TU91jz93B8MOZusxjPmeDfa2Bo">
# <div class="ivm-image-view-model">
# <div class="ivm-view-attr__img-wrapper ivm-view-attr__img-wrapper--use-img-tag display-flex">
# <!-- -->
# <div class="presence-entity presence-entity--size-3">
# <img alt="Anja François RANDRIAVANIAINA" class="presence-entity__image ivm-view-attr__img--centered EntityPhoto-circle-3 EntityPhoto-circle-3 lazy-image ember-view" id="ember415" loading="lazy" src="https://media-exp2.licdn.com/dms/image/C4D03AQHeD08H6blFrQ/profile-displayphoto-shrink_100_100/0/1651601193681?e=1661385600&amp;v=beta&amp;t=q_9LieJQmWUAfTRy_jJ1N4CcBDTtYfY2S4a02yqKpG8"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator hidden presence-indicator--size-3">
# <span class="visually-hidden">
#       Le statut est hors ligne
#       </span>
# </div>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="entity-result__content entity-result__divider pt3 pb3 t-12 t-black--light">
# <div>
# <div class="t-roman t-sans">
# <div class="display-flex">
# <span class="entity-result__title-line entity-result__title-line--2-lines">
# <span class="entity-result__title-text t-16">
# <a class="app-aware-link" href="https://www.linkedin.com/in/anja-fran%C3%A7ois-randriavaniaina-b8342820a?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADUZrpMB_TU91jz93B8MOZusxjPmeDfa2Bo">
# <span dir="ltr"><span aria-hidden="true"><!-- -->Anja François RANDRIAVANIAINA<!-- --></span><span class="visually-hidden"><!-- -->Voir le profil de Anja François RANDRIAVANIAINA<!-- --></span></span>
# </a>
# <span class="entity-result__badge t-14 t-normal t-black--light">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 3e et +<!-- --></span><span class="visually-hidden"><!-- -->Relation de 3e niveau et plus<!-- --></span>
# </span>
# </div>
# </span>
# </span>
# </span>
# <span aria-hidden="true" class="entity-result__badge-overflow align-self-flex-end t-14 t-normal t-black--light flex-shrink-zero entity-result__badge-overflow--visible-2-lines">
# <div class="display-flex flex-row-reverse align-items-baseline">
# <!-- --> <span class="image-text-lockup__text entity-result__badge-text">
# <span aria-hidden="true"><!-- -->• 3e et +<!-- --></span><span class="visually-hidden"><!-- -->Relation de 3e niveau et plus<!-- --></span>
# </span>
# </div>
# </span>
# </div>
# </div>
# <div class="linked-area flex-1 cursor-pointer">
# <div>
# <div class="entity-result__primary-subtitle t-14 t-black t-normal">
# <!-- -->Web Editor<!-- -->
# </div>
# <div class="entity-result__secondary-subtitle t-14 t-normal">
# <!-- -->Antananarivo<!-- -->
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# <!-- --> </div>
# <div class="entity-result__actions entity-result__divider">
# <!-- -->
# <div>
# <button aria-label="Invitez Anja François RANDRIAVANIAINA à rejoindre votre réseau" class="artdeco-button artdeco-button--2 artdeco-button--secondary ember-view" id="ember452"><!-- -->
# <span class="artdeco-button__text">
#     Se connecter
# </span></button>
# <!-- -->
# <!-- -->
# </div>
# </div>
# </div>
# </div>
# <!-- -->
# </li>
# </ul>
# <!-- -->
# <!-- -->
# </div>
# <div class="pv4 display-flex align-items-center artdeco-card pv1 ph0 mb2 search-explicit-feedback-in-content-detail">
# <div class="ml5 mr2">
# <p class="t-sans t-16 t-black t-bold">
#           Ces résultats sont-ils utiles ?
#         </p>
# <p class="t-sans t-14 t-black--light t-normal">
#           Votre feedback nous aide à améliorer les résultats des recherches
#         </p>
# </div>
# <div class="flex-shrink-zero mr5 mlA">
# <button aria-label="Oui, les résultats de cette recherche sont utiles" class="artdeco-button artdeco-button--circle artdeco-button--2 artdeco-button--secondary ember-view" id="ember417"> <li-icon aria-hidden="true" class="artdeco-button__icon" type="thumbs-up-outline"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M19.46 11l-3.91-3.91a7 7 0 01-1.69-2.74l-.49-1.47A2.76 2.76 0 0010.76 1 2.75 2.75 0 008 3.74v1.12a9.19 9.19 0 00.46 2.85L8.89 9H4.12A2.12 2.12 0 002 11.12a2.16 2.16 0 00.92 1.76A2.11 2.11 0 002 14.62a2.14 2.14 0 001.28 2 2 2 0 00-.28 1 2.12 2.12 0 002 2.12v.14A2.12 2.12 0 007.12 22h7.49a8.08 8.08 0 003.58-.84l.31-.16H21V11zM19 19h-1l-.73.37a6.14 6.14 0 01-2.69.63H7.72a1 1 0 01-1-.72l-.25-.87-.85-.41A1 1 0 015 17l.17-1-.76-.74A1 1 0 014.27 14l.66-1.09-.73-1.1a.49.49 0 01.08-.7.48.48 0 01.34-.11h7.05l-1.31-3.92A7 7 0 0110 4.86V3.75a.77.77 0 01.75-.75.75.75 0 01.71.51L12 5a9 9 0 002.13 3.5l4.5 4.5H19z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
# </span></button>
# <button aria-label="Non, les résultats de cette recherche ne sont pas utiles" class="artdeco-button artdeco-button--circle artdeco-button--2 artdeco-button--secondary ember-view ml2" id="ember418"> <li-icon aria-hidden="true" class="artdeco-button__icon" type="thumbs-down-outline"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21 13V3h-2.5l-.31-.16A8.08 8.08 0 0014.61 2H7.13A2.12 2.12 0 005 4.11v.15a2.12 2.12 0 00-2 2.12 2 2 0 00.28 1 2.14 2.14 0 00-1.28 2 2.12 2.12 0 00.91 1.74A2.15 2.15 0 002 12.88 2.12 2.12 0 004.12 15h4.77l-.43 1.29A9.19 9.19 0 008 19.14v1.11A2.75 2.75 0 0010.75 23a2.76 2.76 0 002.61-1.88l.49-1.47a7 7 0 011.69-2.74L19.46 13zm-2-2h-.37l-4.5 4.5A9 9 0 0012 19l-.49 1.47a.75.75 0 01-.71.51.77.77 0 01-.75-.75v-1.09a7 7 0 01.36-2.22L11.67 13h-7a.51.51 0 01-.51-.49.48.48 0 01.09-.29L5 11.13 4.27 10a1 1 0 01.16-1.2l.76-.74L5 7.05a1 1 0 01.62-1l.89-.37.25-.87a1 1 0 011-.72h6.89a6.14 6.14 0 012.69.63L18 5h1z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
# </span></button>
# </div>
# </div>
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# </div>]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [235], in <cell line: 18>()
#      15             nameProfil.append(name)
#      16     return nameProfil
# ---> 18 print(getNewProfilIDs(BeautifulSoup(browser.page_source)))
#      22 """ Obtenir Id de link dans le but d'ajoutée automatiquement des personnes """
#      24 """visitingProfilID = 'in/damien-seniau-347851223/'
#      25 fullLink = 'https://www.linkedin.com/' + visitingProfilID
#      26 browser.get(fullLink)
#    (...)
#      40
#      41 getNewProfilIDs(BeautifulSoup(browser.page_source), profilesQueued)"""
#
# Input In [235], in getNewProfilIDs(soup)
#      11 all_names = pav.findAll('div', {'class': "search-results-container"})
#      12 print(all_names)
# ---> 13 for name in names:
#      14     if name == str(name):
#      15         nameProfil.append(name)
#
# NameError: name 'names' is not defined
